# %% [markdown]
# ## Project 4: To perform Exploratory Data Analysis (EDA) on Zomato restaurants dataset

# %% [markdown]
# <p><b>Submitted by:</b> Muhammad Tabish Sami</p>
# <p><b>Section:</b> Black</p>

# %% [markdown]
# ## A. To read and import dataset.

# %% [markdown]
# <p><b>To import Libraries</b></p>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %% [markdown]
# <p><b>To import the dataset (i.e., zomato_restaurants_in_India.csv)</b></p>
# <p><b>To read the first 5 rows of the given dataset.</b></p>

# %%
df = pd.read_csv(r'C:\Users\ASAD COMPUTERS\Desktop\Data Science\AtomCamp\M2\PYTHON\Project 4\zomato_restaurants_in_India.csv')
df.head()
# Out:
#     res_id                            name      establishment  \
# 0  3400299                     Bikanervala    ['Quick Bites']
# 1  3400005  Mama Chicken Mama Franky House    ['Quick Bites']
# 2  3401013                   Bhagat Halwai    ['Quick Bites']
# 3  3400290                   Bhagat Halwai    ['Quick Bites']
# 4  3401744     The Salt Cafe Kitchen & Bar  ['Casual Dining']
#
#                                                  url  \
# 0  https://www.zomato.com/agra/bikanervala-khanda...
# 1  https://www.zomato.com/agra/mama-chicken-mama-...
# 2  https://www.zomato.com/agra/bhagat-halwai-2-sh...
# 3  https://www.zomato.com/agra/bhagat-halwai-civi...
# 4  https://www.zomato.com/agra/the-salt-cafe-kitc...
#
#                                              address  city  city_id  \
# 0  Kalyani Point, Near Tulsi Cinema, Bypass Road,...  Agra       34
# 1        Main Market, Sadar Bazaar, Agra Cantt, Agra  Agra       34
# ...

# %% [markdown]
# <p><b>To read the last 5 rows of the given dataset.</b></p>

# %%
df.tail()
# Out:
#           res_id                            name      establishment  \
# 211939   3202251  Kali Mirch Cafe And Restaurant  ['Casual Dining']
# 211940   3200996                      Raju Omlet    ['Quick Bites']
# 211941  18984164                The Grand Thakar  ['Casual Dining']
# 211942   3201138                          Subway    ['Quick Bites']
# 211943  18879846     Freshco's - The Health Cafe           ['Café']
#
#                                                       url  \
# 211939  https://www.zomato.com/vadodara/kali-mirch-caf...
# 211940  https://www.zomato.com/vadodara/raju-omlet-kar...
# 211941  https://www.zomato.com/vadodara/the-grand-thak...
# 211942  https://www.zomato.com/vadodara/subway-1-akota...
# 211943  https://www.zomato.com/vadodara/freshcos-the-h...
#
#                                                   address      city  city_id  \
# 211939  Manu Smriti Complex, Near Navrachna School, GI...  Vadodara       32
# ...

# %% [markdown]
# ## B. General Description

# %% [markdown]
# <p><b>To get the general information of the dataset.</b></p>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211944 entries, 0 to 211943
# Data columns (total 26 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   res_id                211944 non-null  int64
#  1   name                  211944 non-null  object
#  2   establishment         211944 non-null  object
#  3   url                   211944 non-null  object
#  4   address               211810 non-null  object
#  5   city                  211944 non-null  object
#  6   city_id               211944 non-null  int64
#  7   locality              211944 non-null  object
#  8   latitude              211944 non-null  float64
#  9   longitude             211944 non-null  float64
#  10  zipcode               48757 non-null   object
#  11  country_id            211944 non-null  int64
#  12  locality_verbose      211944 non-null  object
#  13  cuisines              210553 non-null  object
# ...

# %% [markdown]
# <p><b>Observation:</b></p>
#     <p><b>Data Types:</b> The columns have following <b>integer</b>, <b>float</b>, and <b>object</b> data types.</p>
#     <p><b>Missing Values:</b> It is observed that the following columns <b>zipcode</b>, <b>cuisines</b>, <b>timings</b>, <b>opentable_support</b>, and <b>address</b> have the missing values.</p>

# %% [markdown]
# <p><b>To get the number of rows x column.</b></p>

# %%
df.shape
# Out:
# (211944, 26)

# %% [markdown]
# <p><b>To get the size of dataset.</b></p>

# %%
df.size
# Out:
# 5510544

# %% [markdown]
# <p><b>To get the columns of the dataset.</b></p>

# %%
df.columns
# Out:
# Index(['res_id', 'name', 'establishment', 'url', 'address', 'city', 'city_id',
#        'locality', 'latitude', 'longitude', 'zipcode', 'country_id',
#        'locality_verbose', 'cuisines', 'timings', 'average_cost_for_two',
#        'price_range', 'currency', 'highlights', 'aggregate_rating',
#        'rating_text', 'votes', 'photo_count', 'opentable_support', 'delivery',
#        'takeaway'],
#       dtype='object')

# %% [markdown]
# <p><b>To get the statistical information of the numerical columns.</b></p>

# %%
df.describe()
# Out:
#              res_id        city_id       latitude      longitude  country_id  \
# count  2.119440e+05  211944.000000  211944.000000  211944.000000    211944.0
# mean   1.349411e+07    4746.785434      21.499758      77.615276         1.0
# std    7.883722e+06    5568.766386      22.781331       7.500104         0.0
# min    5.000000e+01       1.000000       0.000000       0.000000         1.0
# 25%    3.301027e+06      11.000000      15.496071      74.877961         1.0
# 50%    1.869573e+07      34.000000      22.514494      77.425971         1.0
# 75%    1.881297e+07   11306.000000      26.841667      80.219323         1.0
# max    1.915979e+07   11354.000000   10000.000000      91.832769         1.0
#
#        average_cost_for_two    price_range  aggregate_rating          votes  \
# count         211944.000000  211944.000000     211944.000000  211944.000000
# mean             595.812229       1.882535          3.395937     378.001864
# ...

# %% [markdown]
# <p><b>Observation:</b></p>
#     <p> By looking at <b>statistical information</b> of numerical columns; we get to know:</p>
#     <p> i. Here, the <b>Median(50%)</b> at <b>1.869573e+07</b> is greater than <b>Mean</b> at <b>1.349411e+07</b>. </p>
#            <p>	Hence, <b>Median > Mean > Mode</b> that shows the data distribution is <b>left-skewed.</b></p>

# %% [markdown]
# <p><b>To get the statistical information of the categorical columns.</b></p>

# %%
df.describe(include='object')
# Out:
#                   name    establishment  \
# count           211944           211944
# unique           41100               27
# top     Domino's Pizza  ['Quick Bites']
# freq              3108            64390
#
#                                                       url  \
# count                                              211944
# unique                                              55568
# top     https://www.zomato.com/chennai/3bs-buddies-bar...
# freq                                                  169
#
#                                  address     city     locality zipcode  \
# count                             211810   211944       211944   48757
# unique                             50657       99         3731    1311
# top     Laxman Jhula, Tapovan, Rishikesh  Chennai  Civil Lines       0
# freq                                 299    11630         3660    7100
#
#              locality_verbose      cuisines         timings currency  \
# ...

# %% [markdown]
# ## C. Duplicate Data Handling

# %% [markdown]
# <p><b>To know the duplicate profile in the dataset.</b></p>

# %%
df.duplicated().sum()
# Out:
# 151527

# %% [markdown]
# <p><b>Observation:</b></p>
#     <p> There are <b>151527</b> duplicate records out of total <b>211944</b> records.</p>
#     <p> Hence, we need to deal with <b>duplicate data handling</b> before further data exploration.</p>

# %% [markdown]
# <p><b>Copying the dataframe "df" to "df_1".</b></p>

# %%
# df_1 is copied to make further amendments.
df_1 = df.copy()
df_1.head(2)
# Out:
#     res_id                            name    establishment  \
# 0  3400299                     Bikanervala  ['Quick Bites']
# 1  3400005  Mama Chicken Mama Franky House  ['Quick Bites']
#
#                                                  url  \
# 0  https://www.zomato.com/agra/bikanervala-khanda...
# 1  https://www.zomato.com/agra/mama-chicken-mama-...
#
#                                              address  city  city_id  \
# 0  Kalyani Point, Near Tulsi Cinema, Bypass Road,...  Agra       34
# 1        Main Market, Sadar Bazaar, Agra Cantt, Agra  Agra       34
#
#      locality   latitude  longitude  ... price_range  currency  \
# 0    Khandari  27.211450  78.002381  ...           2       Rs.
# 1  Agra Cantt  27.160569  78.011583  ...           2       Rs.
#
#                                           highlights aggregate_rating  \
# 0  ['Lunch', 'Takeaway Available', 'Credit Card',...              4.4
# 1  ['Delivery', 'No Alcohol Available', 'Dinner',...              4.4
#
# ...

# %% [markdown]
# <p><b>Eliminating the Duplicate records.</b></p>

# %%
df_1 = df_1.drop_duplicates(keep='first')
df_1
# Out:
#           res_id                            name        establishment  \
# 0        3400299                     Bikanervala      ['Quick Bites']
# 1        3400005  Mama Chicken Mama Franky House      ['Quick Bites']
# 2        3401013                   Bhagat Halwai      ['Quick Bites']
# 3        3400290                   Bhagat Halwai      ['Quick Bites']
# 4        3401744     The Salt Cafe Kitchen & Bar    ['Casual Dining']
# ...          ...                             ...                  ...
# 211882  19142822           Shree Janta Ice Cream  ['Dessert Parlour']
# 211925  18984164                The Grand Thakar    ['Casual Dining']
# 211926  18019952                     Geeta lodge    ['Casual Dining']
# 211940   3200996                      Raju Omlet      ['Quick Bites']
# 211942   3201138                          Subway      ['Quick Bites']
#
#                                                       url  \
# 0       https://www.zomato.com/agra/bikanervala-khanda...
# ...

# %% [markdown]
# <p><b>Observation:</b></p>
#     <p> There were <b>151527</b> duplicate observations out of total <b>211944</b> observations.</p>
#     <p> After <b>deleting/dropping</b> duplicate records, we got <b>60,417</b> observations left.</p>

# %% [markdown]
# ## D. Handling Missing Values

# %% [markdown]
# <p><b> D.1 To find missing values.</b></p>

# %%
df_1.isna().sum()
# Out:
# res_id                      0
# name                        0
# establishment               0
# url                         0
# address                    18
# city                        0
# city_id                     0
# locality                    0
# latitude                    0
# longitude                   0
# zipcode                 47869
# country_id                  0
# locality_verbose            0
# cuisines                  470
# timings                  1070
# average_cost_for_two        0
# price_range                 0
# currency                    0
# highlights                  0
# aggregate_rating            0
# rating_text                 0
# votes                       0
# photo_count                 0
# opentable_support          19
# delivery                    0
# takeaway                    0
# dtype: int64

# %% [markdown]
# <p><b>To find missing values percentage.</b></p>

# %%
print('Amount of missing values in %age :- ')
for column in df_1.columns:
    percentage_missing = np.mean(df_1[column].isna())
    print(f'{column}: {percentage_missing*100:.2f}%')
# Out:
# Amount of missing values in %age :-
# res_id: 0.00%
# name: 0.00%
# establishment: 0.00%
# url: 0.00%
# address: 0.03%
# city: 0.00%
# city_id: 0.00%
# locality: 0.00%
# latitude: 0.00%
# longitude: 0.00%
# zipcode: 79.23%
# country_id: 0.00%
# locality_verbose: 0.00%
# cuisines: 0.78%
# timings: 1.77%
# average_cost_for_two: 0.00%
# price_range: 0.00%
# currency: 0.00%
# highlights: 0.00%
# aggregate_rating: 0.00%
# rating_text: 0.00%
# votes: 0.00%
# photo_count: 0.00%
# opentable_support: 0.03%
# delivery: 0.00%
# takeaway: 0.00%

# %% [markdown]
# <p><b>Observation:</b></p>
#     <p> <b>Zipcode</b> feature has the highest missing values at <b>79.23%</b>, followed by <b>timings</b> at  <b>1.77%</b>, followed by <b>cuisines</b> at <b>0.78%</b>, followed by <b>address</b> at <b>0.03%</b>.</p>

# %% [markdown]
# <p><b>Using Missingno library to briefly overview the missing values in each column.</b></p>

# %% [markdown]
# <p><b> i. Using missingno barplot to view missing values.</b></p>

# %%
bar = msno.bar(df_1)
bar
# Out:
# <Axes: >

# %% [markdown]
# <p><b> ii. Using missingno heatmap.</b></p>

# %%
msno.heatmap(df_1)
# Out:
# <Axes: >

# %% [markdown]
# <p><b> iii. Using missingno matrix.</b></p>

# %%
msno.matrix(df_1)
# Out:
# <Axes: >

# %% [markdown]
# <p><b> iv. Using seaborn heatmap.</b></p>

# %%
sns.heatmap(df_1.isna().transpose())
# Out:
# <Axes: >

# %% [markdown]
# <p><b> D.2: Imputing the missing values.</b></p>

# %% [markdown]
# <p><b> i. For Zipcode </b></p>

# %% [markdown]
# <p><b>zipcode</b> column has the highest missing values percentage at <b>79.23%</b>. </p>
# <p> If we impute this column, it is more likely to make analysis get biased. </p>
# <p> Hence, we will remove this column <b>zipcode</b> to avoid any biasness.</p>

# %%
df_1.drop(['zipcode'],axis=1,inplace=True)

# %%
df_2 = df_1.copy()
df_2.head(2)
# Out:
#     res_id                            name    establishment  \
# 0  3400299                     Bikanervala  ['Quick Bites']
# 1  3400005  Mama Chicken Mama Franky House  ['Quick Bites']
#
#                                                  url  \
# 0  https://www.zomato.com/agra/bikanervala-khanda...
# 1  https://www.zomato.com/agra/mama-chicken-mama-...
#
#                                              address  city  city_id  \
# 0  Kalyani Point, Near Tulsi Cinema, Bypass Road,...  Agra       34
# 1        Main Market, Sadar Bazaar, Agra Cantt, Agra  Agra       34
#
#      locality   latitude  longitude  ...  price_range currency  \
# 0    Khandari  27.211450  78.002381  ...            2      Rs.
# 1  Agra Cantt  27.160569  78.011583  ...            2      Rs.
#
#                                           highlights aggregate_rating  \
# 0  ['Lunch', 'Takeaway Available', 'Credit Card',...              4.4
# 1  ['Delivery', 'No Alcohol Available', 'Dinner',...              4.4
#
# ...

# %% [markdown]
# <p><b> ii. For opentable_support column. </b></p>

# %% [markdown]
# <p><b> opentable_support</b> column had <b>0.03%</b> missing values. </p>
# <p><b> opentable_support</b> column was dropped as it has not much importance due to single repeated value <b>(i.e., 0)</b>. </p>

# %%
df_2.drop(['opentable_support'], axis=1, inplace = True)

# %% [markdown]
# <p><b> iii. For address column. </b></p>

# %% [markdown]
# <p>We have <b>'latitude'</b> and <b>'longitude'</b> column.</p>
# <p>We will use <b> geopy</b> library to impute the missing values in this column.</p>

# %%
# !pip install geopy

# %%
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
# Creating a geocoder object with a higher timeout
geolocator = Nominatim(user_agent="restaurant_geocoder", timeout=10)
# Function to get address from latitude and longitude
def get_address(lat, lon):
    location = geolocator.reverse((lat, lon))
    return location.address if location else None

# Assuming df is your DataFrame and 'latitude', 'longitude', and 'address' are column names
# Fill missing addresses based on latitude and longitude
df_2['address'] = df_2.apply(lambda row: row['address'] if pd.notnull(row['address']) else get_address(row['latitude'], row['longitude']), axis=1)

# %% [markdown]
# <p><b> iv. For timings column. </b></p>

# %% [markdown]
# <p>The <b>timings</b> column has <b>1.77%</b> missing values.</p>
# <p>And, as <b>timings</b> is a categorical column.</p>
#
# <p> Ways to <b>impute/deal</b> with missing values in a categorical column.</p>
#     <p> i.  <b>Delete the missing values record: </b> Deleting a whole record where timing has a missing value is not sufficient.</p>
#     <p> ii. <b>Filling with most frequent value: </b> Filling missing values with a mode in categorical column can lead to biasness. Hence, we will not use mode here.</p>
#     <p> iii.  <b>Imputing with placeholder: </b> Instead of deleting or imputing with mode, we will use a placeholder to impute it.</p>
#
#    <p>When we have a <b>categorical column</b>, it is best to fill the missing values by applying a <b>classifier
#    algorithm</b> to predict missing values.</p>
#    <p> As we have not studied studied yet. We will use placeholder instead </p>

# %%
df_2['timings'] = df_2['timings'].fillna('Not Available')

# %% [markdown]
# <p><b> v. For cuisines column. </b></p>

# %% [markdown]
# <p>The <b>cuisines</b> column has <b>0.78%</b> missing values.</p>
# <p>And, as <b>cuisines</b> is a categorical column.</p>
#
# <p> Ways to <b>impute/deal</b> with missing values in a categorical column.</p>
#     <p> i.  <b>Delete the missing values record: </b> Deleting a whole record where timing has a missing value is not sufficient.</p>
#     <p> ii. <b>Filling with most frequent value: </b> Filling missing values with a mode in categorical column can lead to biasness. Hence, we will not use mode here.</p>
#     <p> iii.  <b>Imputing with placeholder: </b> Instead of deleting or imputing with mode, we will use a placeholder to impute it.</p>
#
#    <p>When we have a <b>categorical column</b>, it is best to fill the missing values by applying a <b>classifier
#    algorithm</b> to predict missing values.</p>
#    <p> As we have not studied studied yet. We will use placeholder instead </p>

# %%
df_2['cuisines']=df_2['cuisines'].fillna('Not Available')

# %% [markdown]
# <p><b> Checking the missing values. </b></p>

# %%
df_2.isna().sum()
# Out:
# res_id                  0
# name                    0
# establishment           0
# url                     0
# address                 0
# city                    0
# city_id                 0
# locality                0
# latitude                0
# longitude               0
# country_id              0
# locality_verbose        0
# cuisines                0
# timings                 0
# average_cost_for_two    0
# price_range             0
# currency                0
# highlights              0
# aggregate_rating        0
# rating_text             0
# votes                   0
# photo_count             0
# delivery                0
# takeaway                0
# dtype: int64

# %% [markdown]
# ## E. Handling Data Type Inconcistencies

# %% [markdown]
# <p><b>Data Type Inconsistencies</b> are as following:</p>
# <p><b>votes column: </b> There are two illogical entries <b>(i.e., Negative values)</b> which will be converted to positive values.</p>
# <p><b>timings column: </b> Special characters <b>(i.e., â€“)</b> in timings column will be replaced with <b>‘to’</b>.</p>

# %% [markdown]
# <p><b>E.1: For votes column</b></p>

# %%
df_2['votes'] = df_2['votes'].abs()

# %%
df_2['votes'].describe()
# Out:
# count    60417.000000
# mean       261.575583
# std        728.283944
# min          0.000000
# 25%          7.000000
# 50%         42.000000
# 75%        207.000000
# max      42539.000000
# Name: votes, dtype: float64

# %% [markdown]
# <p><b>E.2: For timings column</b></p>

# %%
df_2['timings']=df_2['timings'].str.replace('â€“','to',regex=False)

# %%
df_2['timings'].head(100)
# Out:
# 0                            8:30am – 10:30pm (Mon-Sun)
# 1     12:30PM to 12Midnight (Mon, Wed, Thu, Fri, Sat...
# 2                                      9:30 AM to 11 PM
# 3                                  8am – 11pm (Mon-Sun)
# 4                                  11:30 AM to 11:30 PM
#                             ...
# 95                              12noon – 11pm (Mon-Sun)
# 96    12:30pm – 10:30pm (Mon-Thu),12:30pm – 10:45pm ...
# 97                                  8 AM to 12 Midnight
# 98                                        9 AM to 11 PM
# 99                                11am – 10pm (Mon-Sun)
# Name: timings, Length: 100, dtype: object

# %% [markdown]
# ## F. Data Distribution

# %% [markdown]
# <p><b>F.1: Plotting Correlation Matrix.</b></p>

# %% [markdown]
# <p> Correlation matrix will tell us the correlation between variables and developing the general understanding of each varibles </p>

# %% [markdown]
# <p><b>To store all numerical columns in a variable.</b></p>

# %%
numeric_df = df_2.select_dtypes(include=['number'])
numeric_df.columns
# Out:
# Index(['res_id', 'city_id', 'latitude', 'longitude', 'country_id',
#        'average_cost_for_two', 'price_range', 'aggregate_rating', 'votes',
#        'photo_count', 'delivery', 'takeaway'],
#       dtype='object')

# %% [markdown]
# <p><b>To plot correlation matrix.</b></p>

# %%
correlation = numeric_df.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# <p><b>city_id</b> and <b>res_id</b> has strong positive correlation at <b>0.46</b>.</p>
# <p>The correlation coefficient between <b>'price_range'</b> and <b>'average_cost_for_two'</b> is at <b>0.8</b>. It indicates a strong positive correlation between these two variables.</p>
# <p>The correlation coefficient between <b>'votes'</b> and <b>'photo_count'</b> is approximately <b>0.68</b>. It indicates a strong positive correlation between these two variables.</p>

# %% [markdown]
# <p><b>F.2: Outlier Detection.</b></p>

# %% [markdown]
# <p><b>F.2.1: For 'average_cost_for_two'.</b></p>

# %%
df1= sns.boxplot(df_2['average_cost_for_two'])

# %% [markdown]
# <p><b> Observation:</b></p>
#     <p>There are several outliers present, indicated by points
# far above the upper quartile.</p>

# %% [markdown]
# <p><b>F.2.2: For 'price_range'.</b></p>

# %%
df2 = sns.boxplot(df_2['price_range'])

# %% [markdown]
# <p><b> Observation:</b></p>
#     <p>This variable shows a few outliers. However, since price range is
# typically a categorical variable with limited discrete values, these 'outliers' might
# just represent higher-priced establishments.</p>

# %% [markdown]
# <p><b>F.2.3: For 'aggregate_rating'.</b></p>

# %%
df3 = sns.boxplot(df_2['aggregate_rating'])

# %% [markdown]
# <p><b>F.2.4: For 'votes'.</b></p>

# %%
df4 = sns.boxplot(df_2['votes'])

# %% [markdown]
# <p><b> Observation:</b></p>
#     <p>This column shows a significant number of outliers, with some
# establishments having an exceptionally high number of votes.</p>

# %% [markdown]
# <p><b>F.2.5: For 'photo_count'.</b></p>

# %%
df5 = sns.boxplot(df_2['photo_count'])

# %% [markdown]
# <p><b> Observation:</b></p>
#     <p>Similar to votes, there are many outliers with a very high photo
# count.</p>

# %% [markdown]
# <p><b>F.4: Handling Outliers.</b></p>

# %%
df_3 = df_2.copy()
df_3.head(2)
# Out:
#     res_id                            name    establishment  \
# 0  3400299                     Bikanervala  ['Quick Bites']
# 1  3400005  Mama Chicken Mama Franky House  ['Quick Bites']
#
#                                                  url  \
# 0  https://www.zomato.com/agra/bikanervala-khanda...
# 1  https://www.zomato.com/agra/mama-chicken-mama-...
#
#                                              address  city  city_id  \
# 0  Kalyani Point, Near Tulsi Cinema, Bypass Road,...  Agra       34
# 1        Main Market, Sadar Bazaar, Agra Cantt, Agra  Agra       34
#
#      locality   latitude  longitude  ...  average_cost_for_two price_range  \
# 0    Khandari  27.211450  78.002381  ...                   700           2
# 1  Agra Cantt  27.160569  78.011583  ...                   600           2
#
#   currency                                         highlights  \
# 0      Rs.  ['Lunch', 'Takeaway Available', 'Credit Card',...
# ...

# %% [markdown]
# <p><b>F.4.1: For 'average_cost_for_two'.</b></p>

# %% [markdown]
# <p>Applying the <b>log</b> to address the skewness.</p>

# %%
df_3['average_cost_for_two']=np.log(df_3['average_cost_for_two']+1)

# %%
df6 = sns.boxplot(df_3['average_cost_for_two'])

# %% [markdown]
# <p><b>F.4.2: For 'votes'.</b></p>

# %% [markdown]
# <p>Applying the <b>log</b> to address the skewness.</p>

# %%
df_3['votes'] = np.log(df_3['votes']+1)

# %%
df7=sns.boxplot(df_3['votes'])

# %% [markdown]
# <p><b>F.4.2: For 'photo_count'.</b></p>

# %% [markdown]
# <p>Applying the <b>log</b> to address the skewness.</p>

# %%
df_3['photo_count'] = np.log(df_3['photo_count']+1)

# %%
df8 = sns.boxplot(df_3['photo_count'])

# %% [markdown]
# <p><b>F.5: Data Distribution of Key Variables.</b></p>

# %% [markdown]
# <p><b>F.5.1: For 'average_cost_for_two'.</b></p>

# %%
plt.figure(figsize=(8,6))
sns.histplot(df_3['average_cost_for_two'],bins=30,kde=True)
plt.title('Distribution of average_cost_for_two')
plt.xlabel('average_cost_for_two')
plt.ylabel('frequency')
plt.show()

# %% [markdown]
# <p> The <b>distribution or histogram</b> shows that the data distribution is <b>left-skewed</b>.</p>

# %% [markdown]
# <p><b>F.5.2: For 'price_range'.</b></p>

# %%
plt.figure(figsize=(8,6))

sns.histplot(df_3['price_range'],bins=30,kde=True)
plt.title('Distribution of price_range')
plt.xlabel('price_range')
plt.ylabel('frequency')
plt.show()

# %% [markdown]
# <p> The <b>distribution or histogram</b> shows that the data distribution has <b>multimodal</b> distribution with distinct peaks.</p>

# %% [markdown]
# <p><b>F.5.3: For 'aggregate_rating'.</b></p>

# %%
plt.figure(figsize=(8,6))

sns.histplot(df_3['aggregate_rating'],bins=30,kde=True)
plt.title('Distribution of aggregate_rating')
plt.xlabel('aggregate_rating')
plt.ylabel('frequency')
plt.show()

# %% [markdown]
# <p> The <b>distribution or histogram</b> shows that the data distribution is <b>left_skewed</b>.</p>
# <p> It also shows that it has majority ratings falling at <b>3 to 4.5</b>.with fewer restaurants having least ratings at <b>0 to 2</b>.</p>

# %% [markdown]
# <p><b>F.5.4: For 'votes'.</b></p>

# %%
plt.figure(figsize=(8,6))

sns.histplot(df_3['votes'],bins=30,kde=True)
plt.title('Distribution of Votes')
plt.xlabel('votes')
plt.ylabel('frequency')
plt.show()

# %% [markdown]
# <p> The <b>distribution or histogram</b> shows that the data distribution is <b>right_skewed</b>.</p>

# %% [markdown]
# <p><b>F.5.5: For 'photo_count'.</b></p>

# %%
plt.figure(figsize=(8,6))

sns.histplot(df_3['photo_count'],bins=30,kde=True)
plt.title('Distribution of photo_count')
plt.xlabel('photo_count')
plt.ylabel('frequency')
plt.show()

# %% [markdown]
# <p> The <b>distribution or histogram</b> shows that the data distribution is slightly <b>right_skewed</b>.</p>

# %% [markdown]
# <p><b>F.6: Data Distribution of Categorical Columns.</b></p>

# %% [markdown]
# <p><b>F.6.1: For City Distribution.</b></p>

# %%
top_n = 10
city_cat = df_3['city'].value_counts()[:top_n]
plt.figure(figsize=(8,6))
plt.bar(city_cat.index,city_cat.values)
plt.xticks(rotation=90)
plt.title('Distribution of City (Top 10)')
plt.xlabel('City')
plt.ylabel('frequency')
plt.show()

# %% [markdown]
# <p> These cities are most leading <b>Chennai</b>, <b>Mumbai</b>, and <b>Banglore</b>.</p>

# %% [markdown]
# <p><b>F.6.2: For Cuisines Distribution.</b></p>

# %%
top_n = 10
cuisines_cat = df_3['cuisines'].value_counts()[:top_n]
plt.bar(cuisines_cat.index,cuisines_cat.values)
plt.title('Distribution of Cuisines (Top-10)')
plt.xlabel('Cuisines')
plt.ylabel('Frequency')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <p><b>North Indian</b> and <b>Fast Food</b> are the most common cuisines in the given dataset.</p>

# %% [markdown]
# <p><b>F.6.3: For Timings Distribution.</b></p>

# %%
top_n = 10
timings_cat = df_3['timings'].value_counts()[:top_n]
plt.bar(timings_cat.index,timings_cat.values)
plt.title('Distribution of timings (Top-10)')
plt.xlabel('timings')
plt.ylabel('Frequency')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <p><b>11 am to 11 pm</b> are the most common timings for the zomato restaurants and has variations around this range.</p>

# %% [markdown]
# <p><b>F.6.4: For Highlights Distribution.</b></p>

# %%
top_n = 10
highlights_cat = df_3['highlights'].value_counts()[:top_n]
plt.bar(highlights_cat.index,highlights_cat.values)
plt.title('Distribution of Highlights (Top-10)')
plt.xlabel('Highlights')
plt.ylabel('Frequency')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# <p><b>Observation:</b></p>
# <p><b>['Dinner','Takeaway Available','Lunch','Cash','Indoor Seating']</b> and <b>['Dinner','Delivery', 'Lunch', 'Takeaway Available','Cash','Indoor Seating']</b> are the most common highlights for the zomato restaurants.</p>

# %% [markdown]
# ## G. Regional Analysis

# %% [markdown]
# <p><b>G.1: Compare the restaurant trends and customer preferences across different
# cities or regions in India.</b></p>

# %% [markdown]
# <p><b>G.1.1: Top 10 Cities by Average Rating. </b></p>

# %%
city_rating = df_3.groupby('city')['aggregate_rating'].mean().sort_values(ascending=False)
top_cities = city_rating.head(10)
print(top_cities)
#Plotting barplot
plt.figure(figsize=(8,6))
plt.bar(top_cities.index,top_cities.values)
plt.title('Top 10 cities by Average Rating')
plt.xlabel('Cities')
plt.ylabel('Average Rating')
plt.xticks(rotation=90)


plt.show()
# Out:
# city
# Gurgaon         3.872549
# Secunderabad    3.848454
# Mumbai          3.795863
# Hyderabad       3.775751
# New Delhi       3.770005
# Kolkata         3.767233
# Bangalore       3.729641
# Chennai         3.667764
# Noida           3.651648
# Navi Mumbai     3.546094
# Name: aggregate_rating, dtype: float64

# %% [markdown]
# <p><b>Observation:</b></p>
# <p>The average rating for <b>Gurgaon</b> is highest at <b>3.87</b>, followed by <b>Secundrabad</b> at <b>3.85</b>, and <b>Mumbai</b> at <b>3.80</b> </p>

# %% [markdown]
# <p><b>G.1.2: Top 10 Cities by 'average_cost_for_two'. </b></p>

# %%
city_rat = df_1.groupby('city')['average_cost_for_two'].mean().sort_values(ascending=False)
top_city = city_rat.head(10)
print(top_city)
#plotting barplot
plt.bar(top_city.index,top_city.values)
plt.title('Top 10 Cities by Average Cost for Two')
plt.xlabel('City')
plt.ylabel('average_cost_for_two')
plt.xticks(rotation=45)

plt.show()
# Out:
# city
# Mumbai         1101.773050
# Gurgaon        1025.384615
# New Delhi      1018.305360
# Hyderabad       847.322171
# Bangalore       811.602537
# Goa             798.828058
# Noida           759.816850
# Pune            753.095238
# Navi Mumbai     752.382812
# Jaipur          716.222527
# Name: average_cost_for_two, dtype: float64

# %% [markdown]
# <p><b>Observation:</b></p>
# <p>The average_cost_for_two for <b>Mumbai</b> is highest at <b>1101.77</b>, followed by <b>Gurgaon</b> at <b>1025.384615</b>, and <b>New Delhi</b> at <b>1018.305360</b> </p>

# %% [markdown]
# <p><b>G.1.2: Top 3 Cuisines in Top 5 Cities by Restaurants. </b></p>

# %%
#Counting the number of restaurants for each 'cuisines' within each city. 
cities_agg = df_3.groupby(['city','cuisines'])['res_id'].size().reset_index(name='count')
#Finding top-3 cuisines in each city
top_cuisines = (cities_agg.groupby('city', as_index=False)
                            .apply(lambda x:x.nlargest(3,'count'))
                            .reset_index(drop=True))
# To find Top 5 cities
top_cities = cities_agg.groupby('city')['count'].sum().nlargest(5).index
# To filter 'top_cuisines' to include only top 5 cities
top_cuisines_cities = top_cuisines[top_cuisines['city'].isin(top_cities)]
# For Plotting
plot_data = (top_cuisines_cities
             .set_index(['city','cuisines'])
             .unstack('cuisines')['count']
             .fillna(0))
# Plotting the data
plot_data.plot(kind='bar',stacked=True,figsize=(10,7))
plt.title('Top 3 Cuisines in Top 5 Cities by Restaurants')
plt.xlabel('City')
plt.ylabel('Number of Restaurants')
plt.legend(title='cuisines',bbox_to_anchor=(1.0,1.0))
plt.xticks(rotation=90,ha='right')
plt.tight_layout()                                                               
plt.show()

# %% [markdown]
# <p><b>Observation:</b></p>
# <p><b>Banglore</b>, <b>Chennai</b>, and <b>New Delhi</b> are <b>Top 3 cities</b> having top 3 cuisines as <b>Mithai, Street Food, South Indian, and North Indian.</b>, and <b>Finger Food, Ice Cream, Deserts, South Indian </b>, and <b>North Indian, Street Food, (Deserts, Ice cream, and Beverages)</b></p>

# %% [markdown]
# <p><b> G.2: Identify unique characteristics of the dining scene in each region.  </b></p>

# %% [markdown]
# <p><b>G.2.1: Finding Number of Cities in each city to observe dining scene in each region.</b></p>

# %%
locality_establishments = df_3.groupby('city')['establishment'].size().sort_values(ascending=False)
top_locality = locality_establishments.head(5)
print(top_locality)
#plotting bargraph
plt.figure(figsize=(8,6))
plt.bar(top_locality.index,top_locality.values)
plt.title('Number of Top 5 Establishments across each City')
plt.xlabel('City')
plt.ylabel('Number of Establishment')
plt.xticks(rotation=45)
# Out:
# city
# Chennai      2612
# Mumbai       2538
# Bangalore    2365
# Pune         1911
# New Delhi    1847
# Name: establishment, dtype: int64
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'Chennai'),
#   Text(1, 0, 'Mumbai'),
#   Text(2, 0, 'Bangalore'),
#   Text(3, 0, 'Pune'),
#   Text(4, 0, 'New Delhi')])

# %% [markdown]
# <p><b>Observation:</b></p>
# <p><b>Chennai</b> is the leading city with highest number of establishments at <b>2612</b>, followed by <b>Mumbai</b> at <b>2538</b>, and Bangalore at <b>2365.</b>

# %% [markdown]
# ## H. Customer Preference Analysis:

# %% [markdown]
# <p><b> H.1 Analyze the types of cuisines that are popular in different regions.</b></p>

# %%
cuisines_region = df_3.groupby('cuisines')['city'].size().sort_values(ascending=False)
top_cuisines = cuisines_region.head(10)
print(top_cuisines)
# Plotting bar graph
plt.figure(figsize=(8,6))
plt.bar(top_cuisines.index,top_cuisines.values)
plt.title('Top 10 Cuisines across different Regions')
plt.xlabel('Cuisines')
plt.ylabel('Frequency')
plt.xticks(rotation=90)
plt.show()
# Out:
# cuisines
# North Indian             4587
# Fast Food                2137
# North Indian, Chinese    1720
# Bakery                   1618
# South Indian             1600
# Street Food              1221
# Cafe                     1180
# Mithai                   1032
# Desserts                  950
# Bakery, Desserts          872
# Name: city, dtype: int64

# %% [markdown]
# <p><b>Observation:</b></p>
# <p><b>North Indian</b> is the leading cuisine with highest frequency at <b>4587</b>, followed by <b>Fast Food</b> at <b>2137</b>, and North Indian, Chinese at <b>1720.</b>

# %% [markdown]
# <p><b> H.2: Examine the relationship between restaurant ratings, price range, and
# popularity.</b></p>

# %% [markdown]
# <p><b> H.2.1: Plotting Correlation matrix to exmaine relationship between restaurant ratings, price range, and
# popularity.</b></p>

# %% [markdown]
# <p> We will plot the correlation matrix to examine the relationship between different variable. </p>

# %%
correlation = df_3[['votes','aggregate_rating','price_range']].corr()
plt.figure(figsize=(8,6))
sns.heatmap(correlation,annot=True,cmap='coolwarm',fmt='.2f')
plt.title('Correlation Matrix for Votes, aggregate_rating, and price_range')
plt.show()

# %% [markdown]
# <p><b>Observation:</b></p>
# <p><b>Votes</b> and <b>aggregate_rating</b> has the <b>highest positive correlation</b> at <b>0.79</b>, followed by <b>Votes</b> and <b>price_range</b> having moderate positive correlation at <b>0.36</b></p>
# <p><b>aggregate_rating</b> and <b>price_range</b> has the <b>slightly positive correlation</b> at <b>0.26</b>.</p>

# %% [markdown]
# <p><b> H.2.2: Plotting Distribution of individual Variables.</b></p>

# %% [markdown]
# <p><b> H.2.2.1: Plotting Distribution of Restaurant's Name and Aggregate Rating.</b></p>

# %%
restaurants_rating = df_3.groupby('name')['aggregate_rating'].mean().sort_values(ascending=False)
top_restaurants = restaurants_rating.head(10)
print(top_restaurants)
#plotting barcharts
plt.figure(figsize=(8,6))
plt.bar(top_restaurants.index,top_restaurants.values)
plt.title('Distribution of Top 10 Restaurant and Aggregate Rating')
plt.xlabel('Restaurant City')
plt.ylabel('Aggregate Rating')
plt.xticks(rotation=90)
plt.show()
# Out:
# name
# Indish Lounge                      4.9
# Purple Martini                     4.9
# ARK 2.0 - Courtyard By Marriott    4.9
# Buttercupp                         4.9
# Milap's Punjabi Hotel              4.9
# Villa Maya Heritage Restaurant     4.9
# Conçu                              4.9
# Cafe Paashh                        4.9
# Pabbas                             4.9
# Sahib’s Barbeque by Ohri’s         4.9
# Name: aggregate_rating, dtype: float64

# %% [markdown]
# <p><b> H.2.3: Plotting Distribution of Rating by Average Price Range.</b></p>

# %%
rating_range = df_3.groupby('price_range')['aggregate_rating'].mean()
print(rating_range)
# Plotting barcharts
plt.figure(figsize=(8,6))
colors=['red','blue','green','brown']
plt.bar(rating_range.index,rating_range.values,color=colors)
plt.title('Distribution of Average Rating accross Price Range')
plt.xlabel('Price Range')
plt.ylabel('Average Rating')
price_labels=['Low','Moderate','Expensive','Very Expensive']
plt.xticks(rating_range.index)
plt.show()
# Out:
# price_range
# 1    2.669837
# 2    3.281592
# 3    3.577653
# 4    3.701439
# Name: aggregate_rating, dtype: float64

# %% [markdown]
# <p><b>Observation:</b></p>
# <p><b>Price Range at 4</b> has the highest average rating at <b>3.7</b>, followed by <b>Price Range at 3</b> at <b>3.57</b>, and <b>Price Range at 1</b> has the least average rating at <b>2.67</b> </p>

# %% [markdown]
# ## I. Competitive Analysis

# %% [markdown]
# <p><b> I.1: Identify major competitors in each region based on cuisine, pricing, and
# ratings.</b></p>

# %% [markdown]
# <p><b> I.1.1: Finding major competitors in each region based on cuisine, pricing, and
# ratings.</b></p>

# %%
major_competitors = df_2.loc[(df['cuisines'] != 'Not Available') & (df['average_cost_for_two'] != 0) , ['city','cuisines','average_cost_for_two','aggregate_rating']]
duplicate_cities = major_competitors.drop_duplicates(subset='city')
duplicate_cities.nlargest(20,'aggregate_rating')
# Out:
#                 city                                           cuisines  \
# 15114       Amritsar                                 Fast Food, Italian
# 19630      Bangalore  Continental, North Indian, Chinese, European, ...
# 27257   Bhubaneshwar                                 Tex-Mex, Fast Food
# 129079     Mangalore          Ice Cream, Desserts, Beverages, Fast Food
# 134885         Thane  Modern Indian, North Indian, Chinese, Momos, A...
# 151290        Nashik                       Continental, Indian, Chinese
# 173048        Rajkot  North Indian, Gujarati, South Indian, Continental
# 5936           Ajmer  Continental, Beverages, South Indian, Fast Foo...
# 11147      Allahabad                                       North Indian
# 24601         Bhopal  Street Food, South Indian, Fast Food, Desserts...
# 33460        Chennai  North Indian, European, Mediterranean, Contine...
# 134905   Navi Mumbai                      Italian, Continental, Mexican
# ...
